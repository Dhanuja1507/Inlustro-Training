# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("/content/Salary_Data.csv")
data.isnull().sum()
data.head(6)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642

# %%
data.tail(4)
# Out:
#     YearsExperience  Salary
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
data.dtypes
# Out:
# YearsExperience    float64
# Salary               int64
# dtype: object

# %%
data.shape
# Out:
# (30, 2)

# %%
drdata=data[data.duplicated()]
print("new row",drdata.shape)
# Out:
# new row (0, 2)

# %%
data.count()
# Out:
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.boxplot(data=data[["YearsExperience"]],palette="muted")
plt.title("boxplot for salary vs experience ")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x="Salary",palette="muted")
plt.title("countplot for salary")
plt.show()
# Out:
# <ipython-input-10-14e5741fea41>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data,x="Salary",palette="muted")

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=data,x="Salary",y="YearsExperience",palette="coolwarm")
plt.title("barplot for salary vs experience ")
plt.show()
# Out:
# <ipython-input-11-dc1785a7b712>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x="Salary",y="YearsExperience",palette="coolwarm")

# %%
plt.figure(figsize=(8,5))
sns.histplot(data["Salary"],bins=30,kde=True,palette="muted")
plt.title("histogram for salary",fontsize=18)
plt.show()
# Out:
# <ipython-input-12-006d4bc3e127>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data["Salary"],bins=30,kde=True,palette="muted")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split

x=data["YearsExperience"]
y=data["Salary"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test.values.reshape(-1,1))
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(mse)
print(r2)
# Out:
# 37784662.46621314
# 0.9414466227178214

# %%
plt.scatter(x,y,color="blue")
plt.plot(x_test,y_pred,color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Salary vs vs experience")
plt.show()
